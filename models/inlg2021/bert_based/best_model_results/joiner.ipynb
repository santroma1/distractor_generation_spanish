# %%
import pandas as pd
import os

# %%
df = pd.read_csv("gen/del_r_point.csv", index_col=0)
df
# Out:
#                                                    /aure_20000 /aure_22000  \
# Metric                                                   Value       Value
# Total                                                       95          95
# Any of the generated distractors matches with a...      49.47%      47.37%
# The correct answer is among generated distractors        3.16%       3.16%
# Any (but not all) generated distractors are the...       4.21%      14.74%
# All generated distractors are the same                   3.16%       3.16%
# Any distractor is capitalized differently from ...       9.47%       6.32%
# Any distractor contains repetitive words                  0.0%        0.0%
# Any distractor is an empty string                         0.0%        0.0%
# (A) Any distractor is in its own context                95.79%      88.42%
# (B) Any distractor is in any context from train...      35.79%      37.89%
# (C) Any distractor is a distractor from trainin...        0.0%        0.0%
# (A) and (B)                                             35.79%      32.63%
# (A) and (C)                                               0.0%        0.0%
# (A1) All distractors are in their own context           53.68%      43.16%
# (B1) All distractors are in any context from tr...      12.63%      12.63%
# (C1) All distractors are distractors from train...        0.0%        0.0%
# (A1) and (B1)                                           10.53%       6.32%
# (A1) and (C1)                                             0.0%        0.0%
# Distractor recall                                       22.95%      20.33%
#
#                                                    /aure_24000 /aure_26000  \
# Metric                                                   Value       Value
# Total                                                       95          95
# Any of the generated distractors matches with a...      56.84%      54.74%
# The correct answer is among generated distractors        4.21%       3.16%
# Any (but not all) generated distractors are the...       5.26%       7.37%
# All generated distractors are the same                   1.05%       1.05%
# Any distractor is capitalized differently from ...       9.47%       8.42%
# Any distractor contains repetitive words                  0.0%        0.0%
# Any distractor is an empty string                         0.0%        0.0%
# (A) Any distractor is in its own context                97.89%      96.84%
# (B) Any distractor is in any context from train...      36.84%      43.16%
# (C) Any distractor is a distractor from trainin...        0.0%        0.0%
# (A) and (B)                                             36.84%      43.16%
# (A) and (C)                                               0.0%        0.0%
# (A1) All distractors are in their own context           61.05%      63.16%
# (B1) All distractors are in any context from tr...      10.53%      10.53%
# (C1) All distractors are distractors from train...        0.0%        0.0%
# (A1) and (B1)                                            8.42%       8.42%
# (A1) and (C1)                                             0.0%        0.0%
# Distractor recall                                       27.54%      26.56%
#
#                                                    /upml_18000 /upml_20000  \
# Metric                                                   Value       Value
# Total                                                       95          95
# Any of the generated distractors matches with a...      61.05%       60.0%
# The correct answer is among generated distractors        5.26%       3.16%
# Any (but not all) generated distractors are the...       7.37%       5.26%
# All generated distractors are the same                   3.16%       2.11%
# Any distractor is capitalized differently from ...       9.47%      13.68%
# Any distractor contains repetitive words                 1.05%       4.21%
# Any distractor is an empty string                         0.0%        0.0%
# (A) Any distractor is in its own context                90.53%      89.47%
# (B) Any distractor is in any context from train...      34.74%      35.79%
# (C) Any distractor is a distractor from trainin...        0.0%        0.0%
# (A) and (B)                                             32.63%      33.68%
# (A) and (C)                                               0.0%        0.0%
# (A1) All distractors are in their own context           52.63%      45.26%
# (B1) All distractors are in any context from tr...      14.74%      13.68%
# (C1) All distractors are distractors from train...        0.0%        0.0%
# (A1) and (B1)                                           11.58%      10.53%
# (A1) and (C1)                                             0.0%        0.0%
# Distractor recall                                       31.15%      31.48%
#
#                                                    /upml_22000
# Metric                                                   Value
# Total                                                       95
# Any of the generated distractors matches with a...      57.89%
# The correct answer is among generated distractors        3.16%
# Any (but not all) generated distractors are the...       3.16%
# All generated distractors are the same                    0.0%
# Any distractor is capitalized differently from ...      13.68%
# Any distractor contains repetitive words                 5.26%
# Any distractor is an empty string                         0.0%
# (A) Any distractor is in its own context                91.58%
# (B) Any distractor is in any context from train...      34.74%
# (C) Any distractor is a distractor from trainin...        0.0%
# (A) and (B)                                             31.58%
# (A) and (C)                                               0.0%
# (A1) All distractors are in their own context           48.42%
# (B1) All distractors are in any context from tr...      14.74%
# (C1) All distractors are distractors from train...        0.0%
# (A1) and (B1)                                            9.47%
# (A1) and (C1)                                             0.0%
# Distractor recall                                       30.49%

# %%
columns = ["Total", 
           "Distractor recall", 
           "Any of the generated distractors matches with a gold one",
           "(A) Any distractor is in its own context",
           "The correct answer is among generated distractors", 
           "Any (but not all) generated distractors are the same", 
           "All generated distractors are the same",
           "Any distractor contains repetitive words", 
           "Any distractor is an empty string", 
           "(C) Any distractor is a distractor from training data"]

# %%
df.T[columns].T
# Out:
#                                                    /aure_20000 /aure_22000  \
# Total                                                       95          95
# Distractor recall                                       22.95%      20.33%
# Any of the generated distractors matches with a...      49.47%      47.37%
# (A) Any distractor is in its own context                95.79%      88.42%
# The correct answer is among generated distractors        3.16%       3.16%
# Any (but not all) generated distractors are the...       4.21%      14.74%
# All generated distractors are the same                   3.16%       3.16%
# Any distractor contains repetitive words                  0.0%        0.0%
# Any distractor is an empty string                         0.0%        0.0%
# (C) Any distractor is a distractor from trainin...        0.0%        0.0%
#
#                                                    /aure_24000 /aure_26000  \
# Total                                                       95          95
# Distractor recall                                       27.54%      26.56%
# Any of the generated distractors matches with a...      56.84%      54.74%
# (A) Any distractor is in its own context                97.89%      96.84%
# The correct answer is among generated distractors        4.21%       3.16%
# Any (but not all) generated distractors are the...       5.26%       7.37%
# All generated distractors are the same                   1.05%       1.05%
# Any distractor contains repetitive words                  0.0%        0.0%
# Any distractor is an empty string                         0.0%        0.0%
# (C) Any distractor is a distractor from trainin...        0.0%        0.0%
#
#                                                    /upml_18000 /upml_20000  \
# Total                                                       95          95
# Distractor recall                                       31.15%      31.48%
# Any of the generated distractors matches with a...      61.05%       60.0%
# (A) Any distractor is in its own context                90.53%      89.47%
# The correct answer is among generated distractors        5.26%       3.16%
# Any (but not all) generated distractors are the...       7.37%       5.26%
# All generated distractors are the same                   3.16%       2.11%
# Any distractor contains repetitive words                 1.05%       4.21%
# Any distractor is an empty string                         0.0%        0.0%
# (C) Any distractor is a distractor from trainin...        0.0%        0.0%
#
#                                                    /upml_22000
# Total                                                       95
# Distractor recall                                       30.49%
# Any of the generated distractors matches with a...      57.89%
# (A) Any distractor is in its own context                91.58%
# The correct answer is among generated distractors        3.16%
# Any (but not all) generated distractors are the...       3.16%
# All generated distractors are the same                    0.0%
# Any distractor contains repetitive words                 5.26%
# Any distractor is an empty string                         0.0%
# (C) Any distractor is a distractor from trainin...        0.0%
