# %%
import pandas as pd
import os

# %%
df = pd.read_csv("gen/del_r_point.csv", index_col=0)
df
# Out:
#                                                    del_r_point
# Metric                                                   Value
# Total                                                       50
# Any of the generated distractors matches with a...       70.0%
# The correct answer is among generated distractors         6.0%
# Any (but not all) generated distractors are the...        2.0%
# All generated distractors are the same                    0.0%
# Any distractor is capitalized differently from ...       14.0%
# Any distractor contains repetitive words                  4.0%
# Any distractor is an empty string                         0.0%
# (A) Any distractor is in its own context                 94.0%
# (B) Any distractor is in any context from train...       34.0%
# (C) Any distractor is a distractor from trainin...        0.0%
# (A) and (B)                                              34.0%
# (A) and (C)                                               0.0%
# (A1) All distractors are in their own context            50.0%
# (B1) All distractors are in any context from tr...       10.0%
# (C1) All distractors are distractors from train...        0.0%
# (A1) and (B1)                                            10.0%
# (A1) and (C1)                                             0.0%
# Distractor recall                                       35.62%

# %%
columns = ["Total", 
           "Distractor recall", 
           "Any of the generated distractors matches with a gold one",
           "(A) Any distractor is in its own context",
           "The correct answer is among generated distractors", 
           "Any (but not all) generated distractors are the same", 
           "All generated distractors are the same",
           "Any distractor contains repetitive words", 
           "Any distractor is an empty string", 
           "(C) Any distractor is a distractor from training data"]

# %%
df.T[columns].T
# Out:
#                                                    del_r_point
# Total                                                       50
# Distractor recall                                       35.62%
# Any of the generated distractors matches with a...       70.0%
# (A) Any distractor is in its own context                 94.0%
# The correct answer is among generated distractors         6.0%
# Any (but not all) generated distractors are the...        2.0%
# All generated distractors are the same                    0.0%
# Any distractor contains repetitive words                  4.0%
# Any distractor is an empty string                         0.0%
# (C) Any distractor is a distractor from trainin...        0.0%
