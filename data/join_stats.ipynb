# %%
import numpy as np
import pandas as pd
import json

# %%
train = pd.read_csv("training_stats.csv", index_col=0)
dev = pd.read_csv("dev_stats.csv", index_col=0)
test = pd.read_csv("test_stats.csv", index_col=0)

# %%
train
# Out:
#                                   training
# # of texts                             810
# # of MCQs                              835
# # of D                        3.16 +- 0.74
# Len(Text)                  158.21 +- 54.86
# Max(Text)                            453.0
# Len(A)                        4.36 +- 4.49
# Max(A)                                26.0
# Len(D)                        4.59 +- 4.97
# Max(D)                                  43
# |Len(A) - Len(D)|             1.69 +- 2.28
# Max(|Len(A) - Len(D)|)  16.666666666666668

# %%
df = pd.concat([train, dev, test], axis=1)

# %%
df
# Out:
#                                   training                 dev  \
# # of texts                             810                  95
# # of MCQs                              835                  95
# # of D                        3.16 +- 0.74        3.23 +- 0.69
# Len(Text)                  158.21 +- 54.86     158.45 +- 49.53
# Max(Text)                            453.0               297.0
# Len(A)                        4.36 +- 4.49        5.45 +- 4.70
# Max(A)                                26.0                22.0
# Len(D)                        4.59 +- 4.97        5.62 +- 5.53
# Max(D)                                  43                  32
# |Len(A) - Len(D)|             1.69 +- 2.28        2.08 +- 2.52
# Max(|Len(A) - Len(D)|)  16.666666666666668  10.333333333333334
#
#                                    test
# # of texts                           48
# # of MCQs                            50
# # of D                     3.20 +- 0.75
# Len(Text)               158.18 +- 60.75
# Max(Text)                         449.0
# Len(A)                     4.76 +- 4.37
# Max(A)                             19.0
# Len(D)                     4.08 +- 3.46
# Max(D)                               17
# |Len(A) - Len(D)|          1.85 +- 2.00
# Max(|Len(A) - Len(D)|)              8.0
